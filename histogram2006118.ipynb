# %% [markdown]
# <a href="https://colab.research.google.com/github/ilhmahmd/Tugas/blob/main/histogram2006118.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ilham Ahmad Maulana - 2006118

# %% [markdown]
# Upload Gambar

# %%
from google.colab import files

file = files.upload()
# Out:
#      <input type="file" id="files-7899c663-e9c3-4a45-a001-753986301940" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7899c663-e9c3-4a45-a001-753986301940">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Menampilkan Gambar

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread("coba (1).jpg")
cv2_imshow(img)

# size gambar
print(image.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FF2CFC9B590>
# (2072, 2072, 3)

# %% [markdown]
# Fungsi plt dari matplotlib

# %%
import cv2 as cv
from matplotlib import pyplot as plt

coba = cv.cvtColor(cv.imread('coba (1).jpg'), cv.COLOR_BGR2RGB)
plt.imshow(coba)
plt.show()

# %% [markdown]
# Histogram

# %%
color = ('b','g','r')
for i, col in enumerate(color):
  histr = cv2.calcHist([img],[i],None,[256],[0,256])
  plt.plot(histr,color = col)
  plt.xlim([0,256])
plt.show()

# %%
plt.hist(coba.ravel(),256,[0,256]);
plt.show()
